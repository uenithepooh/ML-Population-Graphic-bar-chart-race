# %%
import pandas as pd

# %%
df = pd.read_csv("population.csv")

# %%
df.head()
# Out:
#    Year   Afghanistan       Albania       Algeria  American Samoa  \
# 0  1970  5.198728e+06  2.783043e+06  1.326090e+07    34051.861403
# 1  1971  5.821933e+06  2.787028e+06  1.385400e+07    34417.339576
# 2  1972  6.445139e+06  2.791012e+06  1.444710e+07    34782.817750
# 3  1973  7.068344e+06  2.794997e+06  1.504019e+07    35148.295923
# 4  1974  7.691549e+06  2.798981e+06  1.563329e+07    35513.774096
#
#         Andorra        Angola     Anguilla  Antigua and Barbuda     Argentina  \
# 0  25786.836095  2.610243e+06  5162.498295         58512.761514  2.400916e+07
# 1  26878.460837  3.185991e+06  5365.109686         59167.611343  2.443186e+07
# 2  27970.085578  3.761740e+06  5567.721078         59822.461173  2.485456e+07
# 3  29061.710320  4.337488e+06  5770.332469         60477.311002  2.527726e+07
# 4  30153.335062  4.913237e+06  5972.943860         61132.160832  2.569995e+07
#
#    ...    Uzbekistan       Vanuatu  Vatican City     Venezuela       Vietnam  \
# ...

# %%
df2 = df[['Year','India','Turkey','Germany','China','United States']]

# %%
df2.set_index("Year", inplace = True)

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sum_yearly = df2.cumsum(axis = 0).plot()
sum_yearly
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
pip install bar_chart_race
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ffmpeg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import bar_chart_race as bcr

# %%
df_yarisandata = df[['Year','India','Turkey','Germany','China','United States']]

# %%
df_yarisandata.set_index("Year", inplace = True)

# %%
df_yarisandata
# Out:
#              India        Turkey       Germany         China  United States
# Year
# 1970  5.423604e+08  3.491583e+07  7.755934e+07  8.733653e+08   1.974998e+08
# 1971  5.594558e+08  3.589178e+07  7.766713e+07  8.848168e+08   2.002689e+08
# 1972  5.765513e+08  3.686773e+07  7.777493e+07  8.962682e+08   2.030380e+08
# 1973  5.936467e+08  3.784368e+07  7.788273e+07  9.077197e+08   2.058072e+08
# 1974  6.107421e+08  3.881963e+07  7.799052e+07  9.191711e+08   2.085763e+08
# 1975  6.278376e+08  3.979558e+07  7.809832e+07  9.306226e+08   2.113454e+08
# 1976  6.449330e+08  4.077153e+07  7.820611e+07  9.420741e+08   2.141145e+08
# 1977  6.620285e+08  4.174747e+07  7.831391e+07  9.535255e+08   2.168837e+08
# 1978  6.791239e+08  4.272342e+07  7.842171e+07  9.649770e+08   2.196528e+08
# 1979  6.962193e+08  4.369937e+07  7.852950e+07  9.764285e+08   2.224219e+08
# 1980  7.133148e+08  4.467532e+07  7.863730e+07  9.878799e+08   2.251911e+08
# ...

# %%
df_yarisandata = df_yarisandata.cumsum(axis = 0)

# %%
import seaborn as sns
sns.lineplot(data = df_yarisandata)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
bcr.bar_chart_race(df_yarisandata,filename='population.mp4',figsize=(10,5),title='veri görseleştirme')
# Out:
# C:\Users\LENOVO\AppData\Roaming\Python\Python39\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\LENOVO\AppData\Roaming\Python\Python39\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
